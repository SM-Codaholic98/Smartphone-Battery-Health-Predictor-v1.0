# %%
import pandas as pd
import numpy as np

# Load and merge datasets
independent_features = pd.read_csv('smartphone_battery_features.csv')
dependent_feature = pd.read_csv('smartphone_battery_targets.csv')
df = independent_features.merge(dependent_feature, on='Device_ID', how='inner')

display(df.head())
# Out:
#                               Device_ID  device_age_months  \
# 0  207dd94c-0430-43aa-b388-4893447e628e                 38
# 1  3f4d1d33-ba89-4814-a168-7b4cc75be26b                 28
# 2  b4adca05-564f-4b70-ab69-e8d66e656463                 14
# 3  4147e039-31b7-480a-bbc9-03cd0f66e9f1                 42
# 4  3f9b0fb7-73c2-4ab7-8e30-7b492097a3f5                  7
#
#    battery_capacity_mah  avg_screen_on_hours_per_day  \
# 0                  4500                          7.1
# 1                  3000                          6.8
# 2                  3000                          7.2
# 3                  3000                          5.5
# 4                  3000                          7.6
#
#    avg_charging_cycles_per_week  avg_battery_temp_celsius  \
# 0                          11.4                      34.8
# 1                          10.3                      35.4
# 2                          11.2                      29.4
# 3                           8.3                      32.8
# 4                          11.6                      38.7
#
#    fast_charging_usage_percent  overnight_charging_freq_per_week  \
# 0                         90.8                                 7
# 1                         60.6                                 2
# 2                         29.3                                 4
# 3                         62.5                                 0
# 4                         85.4                                 6
#
#    gaming_hours_per_week  video_streaming_hours_per_week  \
# 0                    7.9                            14.0
# 1                    8.6                            11.0
# 2                    0.3                            10.3
# 3                    1.9                             4.9
# 4                    7.9                             9.3
#
#   background_app_usage_level signal_strength_avg  charging_habit_score  \
# 0                     Medium                Poor                     4
# 1                     Medium                Good                     7
# 2                     Medium                Good                     6
# 3                     Medium                Good                     8
# 4                       High                Good                     5
#
#    usage_intensity_score  thermal_stress_index  \
# 0                   10.0                  4.04
# 1                   10.0                  4.23
# 2                   10.0                  2.21
# 3                   10.0                  3.13
# 4                   10.0                  4.95
#
#    current_battery_health_percent recommended_action
# 0                            32.8       Change Phone
# 1                            50.3    Replace Battery
# 2                            66.1    Replace Battery
# 3                            46.8       Change Phone
# 4                            67.2    Replace Battery

# %%
print("Shape before dropping ID:", df.shape)
df.drop(columns=['Device_ID'], inplace=True)
print("Shape after dropping ID:", df.shape)

print("\nNull Values:\n", df.isnull().sum())
print("\nDuplicated Rows:", df.duplicated().sum())
# Out:
# Shape before dropping ID: (5000, 17)
# Shape after dropping ID: (5000, 16)
#
# Null Values:
#  device_age_months                   0
# battery_capacity_mah                0
# avg_screen_on_hours_per_day         0
# avg_charging_cycles_per_week        0
# avg_battery_temp_celsius            0
# fast_charging_usage_percent         0
# overnight_charging_freq_per_week    0
# gaming_hours_per_week               0
# video_streaming_hours_per_week      0
# background_app_usage_level          0
# signal_strength_avg                 0
# charging_habit_score                0
# usage_intensity_score               0
# thermal_stress_index                0
# current_battery_health_percent      0
# recommended_action                  0
# dtype: int64
#
# Duplicated Rows: 0

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:, :14]
Y = df.iloc[:, 14]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
display(X_train.head())
# Out:
#       device_age_months  battery_capacity_mah  avg_screen_on_hours_per_day  \
# 1840                 13                  5000                          5.7
# 2115                 42                  3000                         10.7
# 4437                 22                  4000                          6.4
# 1146                 32                  3000                          3.5
# 2486                 15                  4000                          7.1
#
#       avg_charging_cycles_per_week  avg_battery_temp_celsius  \
# 1840                           8.4                      34.6
# 2115                          14.2                      36.5
# 4437                           8.8                      33.6
# 1146                           3.6                      32.4
# 2486                          11.5                      38.2
#
#       fast_charging_usage_percent  overnight_charging_freq_per_week  \
# 1840                         62.0                                 1
# 2115                         97.1                                 1
# 4437                         61.1                                 5
# 1146                         22.8                                 7
# 2486                         68.6                                 5
#
#       gaming_hours_per_week  video_streaming_hours_per_week  \
# 1840                    4.2                             7.3
# 2115                    7.4                            12.8
# 4437                    4.9                             8.6
# 1146                    5.6                             8.0
# 2486                   12.6                            11.0
#
#      background_app_usage_level signal_strength_avg  charging_habit_score  \
# 1840                     Medium                Good                     8
# 2115                       High                Good                     6
# 4437                     Medium            Moderate                     5
# 1146                       High                Good                     6
# 2486                       High                Good                     6
#
#       usage_intensity_score  thermal_stress_index
# 1840                   10.0                  3.74
# 2115                   10.0                  4.41
# 4437                   10.0                  3.53
# 1146                   10.0                  3.31
# 2486                   10.0                  5.18

# %%
import joblib
from sklearn.preprocessing import LabelEncoder

label_encoders = {}

for column in X_train.select_dtypes(include='object'):
    le = LabelEncoder()
    X_train[column] = le.fit_transform(X_train[column])
    X_test[column] = le.transform(X_test[column])
    label_encoders[column] = le
    
joblib.dump(label_encoders, 'Label-Encoders.bin')
print("✅ Label Encoders saved as 'Label-Encoders.bin'")
# Out:
# ✅ Label Encoders saved as 'Label-Encoders.bin'

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
X_train = std_scaler.fit_transform(X_train)
X_test = std_scaler.transform(X_test)
    
joblib.dump(std_scaler, 'Standard-Scaler.bin')
print("✅ Standard Scaler saved as 'Standard-Scaler.bin'")
print(f'Training data input shape : {X_train.shape}')
print(f'Testing data input shape  : {X_test.shape}')
# Out:
# ✅ Standard Scaler saved as 'Standard-Scaler.bin'
# Training data input shape : (3500, 14)
# Testing data input shape  : (1500, 14)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor, XGBRFRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.metrics import r2_score
import os

os.environ["LOKY_MAX_CPU_COUNT"] = "8"

classifier_model_dict = {
    'Random Forest Regressor': RandomForestRegressor(random_state=42),
    'AdaBoost Regressor': AdaBoostRegressor(random_state=42),
    'Gradient Boosting Regressor': GradientBoostingRegressor(random_state=42),
    'XGBoost Regressor': XGBRegressor(random_state=42),
    'XGBoost RF-Booster': XGBRFRegressor(random_state=42),
    'LightGBM Regressor': LGBMRegressor(random_state=42),
    'CatBoost Regressor': CatBoostRegressor(verbose=0, random_state=42)
}

for model_name, model in classifier_model_dict.items():
    print(f'\n-------------------- {model_name} --------------------')
    model.fit(X_train, Y_train)
    Y_pred_train = model.predict(X_train)
    Y_pred_test = model.predict(X_test)
    
    print(f"Train R²-Score : {r2_score(Y_train, Y_pred_train):.4f}")
    print(f"Test R²-Score  : {r2_score(Y_test, Y_pred_test):.4f}")
# Out:
# -------------------- Random Forest Regressor --------------------
# Train R²-Score : 0.9941
# Test R²-Score  : 0.9579
#
# -------------------- AdaBoost Regressor --------------------
# Train R²-Score : 0.9366
# Test R²-Score  : 0.9300
#
# -------------------- Gradient Boosting Regressor --------------------
# Train R²-Score : 0.9728
# Test R²-Score  : 0.9635
#
# -------------------- XGBoost Regressor --------------------
# Train R²-Score : 0.9967
# Test R²-Score  : 0.9572
#
# -------------------- XGBoost RF-Booster --------------------
# Train R²-Score : 0.9564
# Test R²-Score  : 0.9424
#
# -------------------- LightGBM Regressor --------------------
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001910 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1321
# [LightGBM] [Info] Number of data points in the train set: 3500, number of used features: 13
# [LightGBM] [Info] Start training from score 62.597257
# Train R²-Score : 0.9854
# Test R²-Score  : 0.9620
#
# -------------------- CatBoost Regressor --------------------
# d:\Predictor_Applications v1.2\Smartphone_Battery_Health_Predictor v1.0\venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\Predictor_Applications v1.2\Smartphone_Battery_Health_Predictor v1.0\venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Train R²-Score : 0.9873
# Test R²-Score  : 0.9645

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Dropout, Reshape, Conv1D, MaxPooling1D, LSTM, GRU, Bidirectional

# 1. Base Deep Neural Network (DNN)
def build_dnn(input_shape):
    inp = Input(shape=input_shape)
    
    x = Dense(256, activation='relu')(inp)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(64, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    # x = Dense(32, activation='relu')(x)
    out = Dense(1)(x)
    
    model = Model(inputs=inp, outputs=out, name="DNN")
    model.compile(optimizer='adam', loss='mae', metrics=['r2_score'])
    return model

# 2. Advanced 3-Block Hybrid Convolutional-Recurrent Networks
def build_advanced_hybrid_dl(input_shape, rnn_type, bidirectional=False, name="Hybrid"):
    inp = Input(shape=input_shape)
    
    # Reshape 1D tabular features to 3D tensor (Batch, Timesteps, Features) for Conv1D
    # Timesteps start at 14
    x = Reshape((input_shape[0], 1))(inp)
    
    # ---------------- Block 1 ----------------
    x = Conv1D(256, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x) # Timesteps reduce to 7
    x = BatchNormalization()(x)
    
    rnn_units_1 = 128 if bidirectional else 256
    rnn_layer_1 = LSTM(rnn_units_1, return_sequences=True) if rnn_type == 'LSTM' else GRU(rnn_units_1, return_sequences=True)
    x = Bidirectional(rnn_layer_1)(x) if bidirectional else rnn_layer_1(x)
    x = Dropout(0.2)(x)
    
    # ---------------- Block 2 ----------------
    x = Conv1D(128, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x) # Timesteps reduce to 3
    x = BatchNormalization()(x)
    
    rnn_units_2 = 64 if bidirectional else 128
    rnn_layer_2 = LSTM(rnn_units_2, return_sequences=True) if rnn_type == 'LSTM' else GRU(rnn_units_2, return_sequences=True)
    x = Bidirectional(rnn_layer_2)(x) if bidirectional else rnn_layer_2(x)
    x = Dropout(0.2)(x)
    
    # ---------------- Block 3 ----------------
    x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x) # Timesteps reduce to 1
    x = BatchNormalization()(x)
    
    rnn_units_3 = 32 if bidirectional else 64
    rnn_layer_3 = LSTM(rnn_units_3, return_sequences=False) if rnn_type == 'LSTM' else GRU(rnn_units_3, return_sequences=False)
    x = Bidirectional(rnn_layer_3)(x) if bidirectional else rnn_layer_3(x)
    x = Dropout(0.2)(x)
    
    # ------------- Dense Output -------------
    # x = Dense(32, activation='relu')(x)
    out = Dense(1)(x)
    
    model = Model(inputs=inp, outputs=out, name=name)
    model.compile(optimizer='adam', loss='mae', metrics=['r2_score'])
    return model

# Define input shape
input_shape = (X_train.shape[1],)

# Initialize all 5 models
dl_models = {
    "DNN": build_dnn(input_shape),
    "CNN-LSTM": build_advanced_hybrid_dl(input_shape, rnn_type='LSTM', bidirectional=False, name="CNN_LSTM"),
    "CNN-BiLSTM": build_advanced_hybrid_dl(input_shape, rnn_type='LSTM', bidirectional=True, name="CNN_BiLSTM"), 
    "CNN-GRU": build_advanced_hybrid_dl(input_shape, rnn_type='GRU', bidirectional=False, name="CNN_GRU"),
    "CNN-BiGRU": build_advanced_hybrid_dl(input_shape, rnn_type='GRU', bidirectional=True, name="CNN_BiGRU")
}

# Preview the architectures
for name, model in dl_models.items():
    print(f"\n{name} Model Summary:")
    model.summary()
# Out:
# DNN Model Summary:
# Model: "DNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │         3,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 46,849 (183.00 KB)
#  Trainable params: 45,953 (179.50 KB)
#  Non-trainable params: 896 (3.50 KB)
# CNN-LSTM Model Summary:
# Model: "CNN_LSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 14, 256)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 7, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 7, 256)         │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 7, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 3, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 3, 128)         │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 3, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 1, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 815,873 (3.11 MB)
#  Trainable params: 814,977 (3.11 MB)
#  Non-trainable params: 896 (3.50 KB)
# CNN-BiLSTM Model Summary:
# Model: "CNN_BiLSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 14, 256)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 7, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 7, 256)         │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 7, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 3, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 3, 128)         │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 3, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 1, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 64)             │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 643,841 (2.46 MB)
#  Trainable params: 642,945 (2.45 MB)
#  Non-trainable params: 896 (3.50 KB)
# CNN-GRU Model Summary:
# Model: "CNN_GRU"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_2 (Reshape)             │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 14, 256)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 7, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 7, 256)         │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 7, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 3, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 3, 128)         │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 3, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 1, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 64)             │        24,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 644,737 (2.46 MB)
#  Trainable params: 643,841 (2.46 MB)
#  Non-trainable params: 896 (3.50 KB)
# CNN-BiGRU Model Summary:
# Model: "CNN_BiGRU"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 14, 256)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_9 (MaxPooling1D)  │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 7, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 7, 256)         │       296,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 7, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_10 (MaxPooling1D) │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 3, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_4 (Bidirectional) │ (None, 3, 128)         │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 3, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_11 (MaxPooling1D) │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 1, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_5 (Bidirectional) │ (None, 64)             │        18,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 515,713 (1.97 MB)
#  Trainable params: 514,817 (1.96 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

dl_history = {}

print('✅ Starting Deep Learning Models Training....\n')

for name, model in dl_models.items():
    print(f"{'='*50}\nTraining {name} Model\n{'='*50}")
    
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    checkpoint = ModelCheckpoint(f'{name}_Model.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=0)
    
    history = model.fit(
        X_train, Y_train, 
        epochs=100, 
        batch_size=32, 
        validation_data=(X_test, Y_test), 
        callbacks=[early_stop, checkpoint], 
        verbose=1
    )
    
    dl_history[name] = history
    print(f"✅ {name} Training Completed. Best model saved as '{name}_Model.keras'\n")
# Out:
# ✅ Starting Deep Learning Models Training....
#
# ==================================================
# Training DNN Model
# ==================================================
# Epoch 1/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 61.8876 - r2_score: -12.1741 - val_loss: 60.9498 - val_r2_score: -11.8834
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 59.0710 - r2_score: -11.1111 - val_loss: 56.8827 - val_r2_score: -10.3193
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 52.7693 - r2_score: -8.8313 - val_loss: 48.7717 - val_r2_score: -7.4767
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42.2686 - r2_score: -5.5182 - val_loss: 36.2833 - val_r2_score: -3.8530
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.6770 - r2_score: -2.0332 - val_loss: 19.1629 - val_r2_score: -0.3564
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.8995 - r2_score: 0.3232 - val_loss: 6.0552 - val_r2_score: 0.8172
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8861 - r2_score: 0.7602 - val_loss: 5.4705 - val_r2_score: 0.8449
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4618 - r2_score: 0.7887 - val_loss: 3.8896 - val_r2_score: 0.9202
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0629 - r2_score: 0.8123 - val_loss: 3.8109 - val_r2_score: 0.9243
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1594 - r2_score: 0.8095 - val_loss: 3.2062 - val_r2_score: 0.9471
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3263 - r2_score: 0.7989 - val_loss: 3.1952 - val_r2_score: 0.9470
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8461 - r2_score: 0.8279 - val_loss: 2.9529 - val_r2_score: 0.9557
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6878 - r2_score: 0.8355 - val_loss: 2.9093 - val_r2_score: 0.9564
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7898 - r2_score: 0.8298 - val_loss: 2.9117 - val_r2_score: 0.9563
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.9377 - r2_score: 0.8207 - val_loss: 2.8289 - val_r2_score: 0.9589
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6913 - r2_score: 0.8354 - val_loss: 3.0003 - val_r2_score: 0.9540
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8060 - r2_score: 0.8312 - val_loss: 2.8524 - val_r2_score: 0.9577
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6303 - r2_score: 0.8406 - val_loss: 2.9067 - val_r2_score: 0.9568
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6605 - r2_score: 0.8361 - val_loss: 2.9481 - val_r2_score: 0.9555
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5163 - r2_score: 0.8446 - val_loss: 2.7594 - val_r2_score: 0.9611
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5831 - r2_score: 0.8443 - val_loss: 2.8404 - val_r2_score: 0.9585
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5287 - r2_score: 0.8445 - val_loss: 2.8778 - val_r2_score: 0.9577
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6317 - r2_score: 0.8382 - val_loss: 2.8507 - val_r2_score: 0.9581
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3595 - r2_score: 0.8525 - val_loss: 2.8315 - val_r2_score: 0.9586
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4208 - r2_score: 0.8523 - val_loss: 2.8245 - val_r2_score: 0.9593
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4787 - r2_score: 0.8458 - val_loss: 2.7070 - val_r2_score: 0.9624
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2818 - r2_score: 0.8580 - val_loss: 2.7386 - val_r2_score: 0.9616
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4547 - r2_score: 0.8488 - val_loss: 3.0268 - val_r2_score: 0.9536
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3908 - r2_score: 0.8529 - val_loss: 2.8398 - val_r2_score: 0.9587
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2702 - r2_score: 0.8576 - val_loss: 2.8667 - val_r2_score: 0.9581
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.
100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.2367 - r2_score: 0.8599 - val_loss: 6.1808 - val_r2_score: 0.6239
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.5201 - r2_score: 0.8461 - val_loss: 3.7071 - val_r2_score: 0.9303
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.1497 - r2_score: 0.8656 - val_loss: 4.1125 - val_r2_score: 0.8842
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.1162 - r2_score: 0.8684 - val_loss: 3.6807 - val_r2_score: 0.9275
# Epoch 32/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.1830 - r2_score: 0.8648 - val_loss: 3.5386 - val_r2_score: 0.9296
# Epoch 33/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.0228 - r2_score: 0.8728 - val_loss: 3.6577 - val_r2_score: 0.9313
# Epoch 34/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.0748 - r2_score: 0.8721 - val_loss: 3.3403 - val_r2_score: 0.9412
# Epoch 35/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.0268 - r2_score: 0.8724 - val_loss: 3.3628 - val_r2_score: 0.9413
# Epoch 36/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.9321 - r2_score: 0.8780 - val_loss: 3.4851 - val_r2_score: 0.9375
# Epoch 37/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.8730 - r2_score: 0.8791 - val_loss: 3.4699 - val_r2_score: 0.9383
# Epoch 38/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.9309 - r2_score: 0.8774 - val_loss: 3.3401 - val_r2_score: 0.9424
# Epoch 39/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 4.8501 - r2_score: 0.8795 - val_loss: 3.3218 - val_r2_score: 0.9433
# Epoch 40/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.9586 - r2_score: 0.8745 - val_loss: 3.4899 - val_r2_score: 0.9351
# Epoch 41/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.8939 - r2_score: 0.8786 - val_loss: 3.5558 - val_r2_score: 0.9248
# Epoch 42/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.8572 - r2_score: 0.8803 - val_loss: 3.5746 - val_r2_score: 0.9359
# Epoch 43/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.8709 - r2_score: 0.8805 - val_loss: 3.3845 - val_r2_score: 0.9407
# Epoch 44/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.8058 - r2_score: 0.8834 - val_loss: 3.4909 - val_r2_score: 0.9383
# Epoch 45/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.8703 - r2_score: 0.8804 - val_loss: 3.4794 - val_r2_score: 0.9384
# Epoch 46/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.6374 - r2_score: 0.8914 - val_loss: 3.4534 - val_r2_score: 0.9390
# Epoch 47/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.7556 - r2_score: 0.8862 - val_loss: 3.3513 - val_r2_score: 0.9423
# Epoch 48/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.8914 - r2_score: 0.8788 - val_loss: 3.5273 - val_r2_score: 0.9373
# Epoch 49/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.8048 - r2_score: 0.8832 - val_loss: 3.7005 - val_r2_score: 0.9297
# ✅ CNN-BiLSTM Training Completed. Best model saved as 'CNN-BiLSTM_Model.keras'
#
# ==================================================
# Training CNN-GRU Model
# ==================================================
# Epoch 1/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - loss: 57.2514 - r2_score: -10.4867 - val_loss: 53.0788 - val_r2_score: -9.0888
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 50.7588 - r2_score: -8.2620 - val_loss: 45.1790 - val_r2_score: -6.5212
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 39.4418 - r2_score: -4.8700 - val_loss: 31.9497 - val_r2_score: -3.1174
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 28.0359 - r2_score: -2.2926 - val_loss: 21.7654 - val_r2_score: -1.1117
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 19.4044 - r2_score: -0.7346 - val_loss: 16.6834 - val_r2_score: -0.3074
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 15.3849 - r2_score: -0.1299 - val_loss: 14.4696 - val_r2_score: 0.0082
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 12.6430 - r2_score: 0.2118 - val_loss: 12.0531 - val_r2_score: 0.3143
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 10.6909 - r2_score: 0.4364 - val_loss: 9.4878 - val_r2_score: 0.5532
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 9.2133 - r2_score: 0.5773 - val_loss: 8.6963 - val_r2_score: 0.6191
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss:
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.1479 - r2_score: 0.8647 - val_loss: 3.5063 - val_r2_score: 0.9354
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.1120 - r2_score: 0.8684 - val_loss: 3.4012 - val_r2_score: 0.9401
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.2053 - r2_score: 0.8619 - val_loss: 3.6836 - val_r2_score: 0.9208
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.0506 - r2_score: 0.8718 - val_loss: 3.5937 - val_r2_score: 0.9332
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.1828 - r2_score: 0.8652 - val_loss: 4.6611 - val_r2_score: 0.8948
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.9856 - r2_score: 0.8758 - val_loss: 3.5034 - val_r2_score: 0.8941
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.0034 - r2_score: 0.8705 - val_loss: 3.2781 - val_r2_score: 0.9440
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.8968 - r2_score: 0.8797 - val_loss: 3.2419 - val_r2_score: 0.9451
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.7358 - r2_score: 0.8866 - val_loss: 3.3412 - val_r2_score: 0.9429
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.7390 - r2_score: 0.8867 - val_loss: 3.2784 - val_r2_score: 0.9449
# Epoch 32/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.9143 - r2_score: 0.8797 - val_loss: 3.5078 - val_r2_score: 0.9368
# Epoch 33/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.7810 - r2_score: 0.8850 - val_loss: 3.4828 - val_r2_score: 0.9390
# Epoch 34/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.9200 - r2_score: 0.8792 - val_loss: 3.2875 - val_r2_score: 0.9444
# Epoch 35/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.7994 - r2_score: 0.8829 - val_loss: 3.6059 - val_r2_score: 0.9336
# Epoch 36/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.8827 - r2_score: 0.8815 - val_loss: 3.3204 - val_r2_score: 0.9431
# Epoch 37/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.7777 - r2_score: 0.8852 - val_loss: 3.4656 - val_r2_score: 0.9390
# Epoch 38/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.7413 - r2_score: 0.8872 - val_loss: 3.7687 - val_r2_score: 0.9134
# Epoch 39/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.7399 - r2_score: 0.8880 - val_loss: 3.5367 - val_r2_score: 0.9356
# ✅ CNN-BiGRU Training Completed. Best model saved as 'CNN-BiGRU_Model.keras'

# %%
results = []

for name, model in dl_models.items():
    Y_pred_train = model.predict(X_train, verbose=0)
    Y_pred_test = model.predict(X_test, verbose=0)
    
    train_r2 = r2_score(Y_train, Y_pred_train)
    test_r2 = r2_score(Y_test, Y_pred_test)
    
    results.append({"DL Model": name, "Train R²-Score": train_r2, "Test R²-Score": test_r2})

results_df = pd.DataFrame(results)
display(results_df)
# Out:
#      DL Model  Train R²-Score  Test R²-Score
# 0         DNN        0.968491       0.962389
# 1    CNN-LSTM        0.960556       0.942739
# 2  CNN-BiLSTM        0.960108       0.943308
# 3     CNN-GRU        0.957431       0.943746
# 4   CNN-BiGRU        0.960513       0.945078

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_models = len(dl_models)
fig, axes = plt.subplots(num_models, 2, figsize=(15, 4 * num_models))

for i, (name, history) in enumerate(dl_history.items()):
    # 1. Plot R²-Score
    axes[i, 0].plot(history.history['r2_score'], label='Train R²-Score', color='blue')
    axes[i, 0].plot(history.history['val_r2_score'], label='Validation R²-Score', color='orange')
    axes[i, 0].set_title(f'{name} - R²-Score')
    axes[i, 0].set_xlabel('Epochs')
    axes[i, 0].set_ylabel('R²-Score')
    axes[i, 0].legend()
    axes[i, 0].grid(True)

    # 2. Plot Loss
    axes[i, 1].plot(history.history['loss'], label='Train Loss (MAE)', color='blue')
    axes[i, 1].plot(history.history['val_loss'], label='Validation Loss (MAE)', color='orange')
    axes[i, 1].set_title(f'{name} - Loss')
    axes[i, 1].set_xlabel('Epochs')
    axes[i, 1].set_ylabel('Loss')
    axes[i, 1].legend()
    axes[i, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model

# Prepare the full dataset for prediction
X_full = df.iloc[:, :14].copy()

encoders = joblib.load('Label-Encoders.bin')
for column in X_full.select_dtypes(include='object'):
    X_full[column] = encoders[column].transform(X_full[column])

scaler = joblib.load('Standard-Scaler.bin')
X_full_scaled = scaler.transform(X_full)

print("Generating predictions for the full dataset using all Deep Learning models...\n")

# Predict with each saved model and append as a new column
for name in dl_models.keys():
    saved_model = load_model(f'{name}_Model.keras')
    predictions = saved_model.predict(X_full_scaled, verbose=0)
    df[f'{name}_Predicted_Output'] = predictions

# Save final dataset
output_file = 'smartphone_battery_health_with_all_predictions.csv'
df.to_csv(output_file, index=False)
print(f"✅ Predictions saved successfully to: {output_file}\n")

# View the original targets alongside the new predictions
display_columns = ['current_battery_health_percent'] + [f'{name}_Predicted_Output' for name in dl_models.keys()]
display(df[display_columns].head())
# Out:
# Generating predictions for the full dataset using all Deep Learning models...
#
# ✅ Predictions saved successfully to: smartphone_battery_health_with_all_predictions.csv
#    current_battery_health_percent  DNN_Predicted_Output  \
# 0                            32.8             31.805159
# 1                            50.3             50.361187
# 2                            66.1             71.790604
# 3                            46.8             43.440388
# 4                            67.2             69.592514
#
#    CNN-LSTM_Predicted_Output  CNN-BiLSTM_Predicted_Output  \
# 0                  35.231880                    32.539547
# 1                  51.821136                    49.424149
# 2                  69.703094                    71.720390
# 3                  41.311234                    41.897873
# 4                  68.644897                    68.034119
#
#    CNN-GRU_Predicted_Output  CNN-BiGRU_Predicted_Output
# 0                 33.117264                   32.353077
# 1                 51.302418                   50.635178
# 2                 70.747391                   71.026169
# 3                 44.460247                   46.458225
# 4                 66.095627                   68.607880

# %%
df[display_columns].head(10)
# Out:
#    current_battery_health_percent  DNN_Predicted_Output  \
# 0                            32.8             31.805159
# 1                            50.3             50.361187
# 2                            66.1             71.790604
# 3                            46.8             43.440388
# 4                            67.2             69.592514
# 5                            69.5             66.947220
# 6                            35.5             37.161182
# 7                            66.3             65.703796
# 8                            56.7             54.786674
# 9                            85.2             83.271095
#
#    CNN-LSTM_Predicted_Output  CNN-BiLSTM_Predicted_Output  \
# 0                  35.231880                    32.539547
# 1                  51.821136                    49.424149
# 2                  69.703094                    71.720390
# 3                  41.311234                    41.897873
# 4                  68.644897                    68.034119
# 5                  65.151894                    67.168694
# 6                  36.008373                    35.209579
# 7                  67.867027                    70.149155
# 8                  57.420906                    53.713852
# 9                  79.402153                    83.864899
#
#    CNN-GRU_Predicted_Output  CNN-BiGRU_Predicted_Output
# 0                 33.117264                   32.353077
# 1                 51.302418                   50.635178
# 2                 70.747391                   71.026169
# 3                 44.460247                   46.458225
# 4                 66.095627                   68.607880
# 5                 64.559746                   65.661514
# 6                 34.904507                   35.678024
# 7                 67.280136                   69.974716
# 8                 53.041149                   54.218246
# 9                 81.181793                   77.397675
