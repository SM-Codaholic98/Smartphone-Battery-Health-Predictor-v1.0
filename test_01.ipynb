# %%
import pandas as pd
import numpy as np

# Load and merge datasets
independent_features = pd.read_csv('smartphone_battery_features.csv')
dependent_feature = pd.read_csv('smartphone_battery_targets.csv')
df = independent_features.merge(dependent_feature, on='Device_ID', how='inner')

display(df.head())
# Out:
#                               Device_ID  device_age_months  \
# 0  207dd94c-0430-43aa-b388-4893447e628e                 38
# 1  3f4d1d33-ba89-4814-a168-7b4cc75be26b                 28
# 2  b4adca05-564f-4b70-ab69-e8d66e656463                 14
# 3  4147e039-31b7-480a-bbc9-03cd0f66e9f1                 42
# 4  3f9b0fb7-73c2-4ab7-8e30-7b492097a3f5                  7
#
#    battery_capacity_mah  avg_screen_on_hours_per_day  \
# 0                  4500                          7.1
# 1                  3000                          6.8
# 2                  3000                          7.2
# 3                  3000                          5.5
# 4                  3000                          7.6
#
#    avg_charging_cycles_per_week  avg_battery_temp_celsius  \
# 0                          11.4                      34.8
# 1                          10.3                      35.4
# 2                          11.2                      29.4
# 3                           8.3                      32.8
# 4                          11.6                      38.7
#
#    fast_charging_usage_percent  overnight_charging_freq_per_week  \
# 0                         90.8                                 7
# 1                         60.6                                 2
# 2                         29.3                                 4
# 3                         62.5                                 0
# 4                         85.4                                 6
#
#    gaming_hours_per_week  video_streaming_hours_per_week  \
# 0                    7.9                            14.0
# 1                    8.6                            11.0
# 2                    0.3                            10.3
# 3                    1.9                             4.9
# 4                    7.9                             9.3
#
#   background_app_usage_level signal_strength_avg  charging_habit_score  \
# 0                     Medium                Poor                     4
# 1                     Medium                Good                     7
# 2                     Medium                Good                     6
# 3                     Medium                Good                     8
# 4                       High                Good                     5
#
#    usage_intensity_score  thermal_stress_index  \
# 0                   10.0                  4.04
# 1                   10.0                  4.23
# 2                   10.0                  2.21
# 3                   10.0                  3.13
# 4                   10.0                  4.95
#
#    current_battery_health_percent recommended_action
# 0                            32.8       Change Phone
# 1                            50.3    Replace Battery
# 2                            66.1    Replace Battery
# 3                            46.8       Change Phone
# 4                            67.2    Replace Battery

# %%
print("Shape before dropping ID:", df.shape)
df.drop(columns=['Device_ID'], inplace=True)
print("Shape after dropping ID:", df.shape)

print("\nNull Values:\n", df.isnull().sum())
print("\nDuplicated Rows:", df.duplicated().sum())
# Out:
# Shape before dropping ID: (5000, 17)
# Shape after dropping ID: (5000, 16)
#
# Null Values:
#  device_age_months                   0
# battery_capacity_mah                0
# avg_screen_on_hours_per_day         0
# avg_charging_cycles_per_week        0
# avg_battery_temp_celsius            0
# fast_charging_usage_percent         0
# overnight_charging_freq_per_week    0
# gaming_hours_per_week               0
# video_streaming_hours_per_week      0
# background_app_usage_level          0
# signal_strength_avg                 0
# charging_habit_score                0
# usage_intensity_score               0
# thermal_stress_index                0
# current_battery_health_percent      0
# recommended_action                  0
# dtype: int64
#
# Duplicated Rows: 0

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:, :14]
Y = df.iloc[:, 14]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
display(X_train.head())
# Out:
#       device_age_months  battery_capacity_mah  avg_screen_on_hours_per_day  \
# 1840                 13                  5000                          5.7
# 2115                 42                  3000                         10.7
# 4437                 22                  4000                          6.4
# 1146                 32                  3000                          3.5
# 2486                 15                  4000                          7.1
#
#       avg_charging_cycles_per_week  avg_battery_temp_celsius  \
# 1840                           8.4                      34.6
# 2115                          14.2                      36.5
# 4437                           8.8                      33.6
# 1146                           3.6                      32.4
# 2486                          11.5                      38.2
#
#       fast_charging_usage_percent  overnight_charging_freq_per_week  \
# 1840                         62.0                                 1
# 2115                         97.1                                 1
# 4437                         61.1                                 5
# 1146                         22.8                                 7
# 2486                         68.6                                 5
#
#       gaming_hours_per_week  video_streaming_hours_per_week  \
# 1840                    4.2                             7.3
# 2115                    7.4                            12.8
# 4437                    4.9                             8.6
# 1146                    5.6                             8.0
# 2486                   12.6                            11.0
#
#      background_app_usage_level signal_strength_avg  charging_habit_score  \
# 1840                     Medium                Good                     8
# 2115                       High                Good                     6
# 4437                     Medium            Moderate                     5
# 1146                       High                Good                     6
# 2486                       High                Good                     6
#
#       usage_intensity_score  thermal_stress_index
# 1840                   10.0                  3.74
# 2115                   10.0                  4.41
# 4437                   10.0                  3.53
# 1146                   10.0                  3.31
# 2486                   10.0                  5.18

# %%
import joblib
from sklearn.preprocessing import LabelEncoder

label_encoders = {}

for column in X_train.select_dtypes(include='object'):
    le = LabelEncoder()
    X_train[column] = le.fit_transform(X_train[column])
    X_test[column] = le.transform(X_test[column])
    label_encoders[column] = le
    
joblib.dump(label_encoders, 'Label-Encoders.bin')
print("✅ Label Encoders saved as 'Label-Encoders.bin'")
# Out:
# ✅ Label Encoders saved as 'Label-Encoders.bin'

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
X_train = std_scaler.fit_transform(X_train)
X_test = std_scaler.transform(X_test)
    
joblib.dump(std_scaler, 'Standard-Scaler.bin')
print("✅ Standard Scaler saved as 'Standard-Scaler.bin'")
print(f'Training data input shape : {X_train.shape}')
print(f'Testing data input shape  : {X_test.shape}')
# Out:
# ✅ Standard Scaler saved as 'Standard-Scaler.bin'
# Training data input shape : (3500, 14)
# Testing data input shape  : (1500, 14)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor, XGBRFRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.metrics import r2_score
import os

os.environ["LOKY_MAX_CPU_COUNT"] = "8"

classifier_model_dict = {
    'Random Forest Regressor': RandomForestRegressor(random_state=42),
    'AdaBoost Regressor': AdaBoostRegressor(random_state=42),
    'Gradient Boosting Regressor': GradientBoostingRegressor(random_state=42),
    'XGBoost Regressor': XGBRegressor(random_state=42),
    'XGBoost RF-Booster': XGBRFRegressor(random_state=42),
    'LightGBM Regressor': LGBMRegressor(random_state=42),
    'CatBoost Regressor': CatBoostRegressor(verbose=0, random_state=42)
}

for model_name, model in classifier_model_dict.items():
    print(f'\n-------------------- {model_name} --------------------')
    model.fit(X_train, Y_train)
    Y_pred_train = model.predict(X_train)
    Y_pred_test = model.predict(X_test)
    
    print(f"Train R²-Score : {r2_score(Y_train, Y_pred_train):.4f}")
    print(f"Test R²-Score  : {r2_score(Y_test, Y_pred_test):.4f}")
# Out:
# -------------------- Random Forest Regressor --------------------
# Train R²-Score : 0.9941
# Test R²-Score  : 0.9579
#
# -------------------- AdaBoost Regressor --------------------
# Train R²-Score : 0.9366
# Test R²-Score  : 0.9300
#
# -------------------- Gradient Boosting Regressor --------------------
# Train R²-Score : 0.9728
# Test R²-Score  : 0.9635
#
# -------------------- XGBoost Regressor --------------------
# Train R²-Score : 0.9967
# Test R²-Score  : 0.9572
#
# -------------------- XGBoost RF-Booster --------------------
# Train R²-Score : 0.9564
# Test R²-Score  : 0.9424
#
# -------------------- LightGBM Regressor --------------------
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000824 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1321
# [LightGBM] [Info] Number of data points in the train set: 3500, number of used features: 13
# [LightGBM] [Info] Start training from score 62.597257
# Train R²-Score : 0.9854
# Test R²-Score  : 0.9620
#
# -------------------- CatBoost Regressor --------------------
# d:\Predictor_Applications v1.2\Smartphone_Battery_Health_Predictor v1.0\venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\Predictor_Applications v1.2\Smartphone_Battery_Health_Predictor v1.0\venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Train R²-Score : 0.9873
# Test R²-Score  : 0.9645

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Dropout, Reshape, Conv1D, MaxPooling1D, LSTM, GRU, Bidirectional

# 1. Base Deep Neural Network (DNN)
def build_dnn(input_shape):
    inp = Input(shape=input_shape)
    
    x = Dense(512, activation='relu')(inp)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(64, activation='relu')(x)
    out = Dense(1)(x)
    
    model = Model(inputs=inp, outputs=out, name="DNN")
    model.compile(optimizer='adam', loss='mae', metrics=['r2_score'])
    return model

# 2. Advanced 3-Block Hybrid Convolutional-Recurrent Networks
def build_advanced_hybrid_dl(input_shape, rnn_type, bidirectional=False, name="Hybrid"):
    inp = Input(shape=input_shape)
    
    # Reshape 1D tabular features to 3D tensor (Batch, Timesteps, Features) for Conv1D
    # Timesteps start at 14
    x = Reshape((input_shape[0], 1))(inp)
    
    # ---------------- Block 1 ----------------
    x = Conv1D(512, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x) # Timesteps reduce to 7
    x = BatchNormalization()(x)
    
    rnn_units_1 = 256 if bidirectional else 512
    rnn_layer_1 = LSTM(rnn_units_1, return_sequences=True) if rnn_type == 'LSTM' else GRU(rnn_units_1, return_sequences=True)
    x = Bidirectional(rnn_layer_1)(x) if bidirectional else rnn_layer_1(x)
    x = Dropout(0.2)(x)
    
    # ---------------- Block 2 ----------------
    x = Conv1D(256, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x) # Timesteps reduce to 3
    x = BatchNormalization()(x)
    
    rnn_units_2 = 128 if bidirectional else 256
    rnn_layer_2 = LSTM(rnn_units_2, return_sequences=True) if rnn_type == 'LSTM' else GRU(rnn_units_2, return_sequences=True)
    x = Bidirectional(rnn_layer_2)(x) if bidirectional else rnn_layer_2(x)
    x = Dropout(0.2)(x)
    
    # ---------------- Block 3 ----------------
    x = Conv1D(128, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x) # Timesteps reduce to 1
    x = BatchNormalization()(x)
    
    rnn_units_3 = 64 if bidirectional else 128
    rnn_layer_3 = LSTM(rnn_units_3, return_sequences=False) if rnn_type == 'LSTM' else GRU(rnn_units_3, return_sequences=False)
    x = Bidirectional(rnn_layer_3)(x) if bidirectional else rnn_layer_3(x)
    x = Dropout(0.2)(x)
    
    # ------------- Dense Output -------------
    x = Dense(64, activation='relu')(x)
    out = Dense(1)(x)
    
    model = Model(inputs=inp, outputs=out, name=name)
    model.compile(optimizer='adam', loss='mae', metrics=['r2_score'])
    return model

# Define input shape
input_shape = (X_train.shape[1],)

# Initialize all 5 models
dl_models = {
    "DNN": build_dnn(input_shape),
    "CNN-LSTM": build_advanced_hybrid_dl(input_shape, rnn_type='LSTM', bidirectional=False, name="CNN_LSTM"),
    "CNN-BiLSTM": build_advanced_hybrid_dl(input_shape, rnn_type='LSTM', bidirectional=True, name="CNN_BiLSTM"), 
    "CNN-GRU": build_advanced_hybrid_dl(input_shape, rnn_type='GRU', bidirectional=False, name="CNN_GRU"),
    "CNN-BiGRU": build_advanced_hybrid_dl(input_shape, rnn_type='GRU', bidirectional=True, name="CNN_BiGRU")
}

# Preview the architectures
for name, model in dl_models.items():
    print(f"\n{name} Model Summary:")
    model.summary()
# Out:
# DNN Model Summary:
# Model: "DNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │         7,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 183,809 (718.00 KB)
#  Trainable params: 182,017 (711.00 KB)
#  Non-trainable params: 1,792 (7.00 KB)
# CNN-LSTM Model Summary:
# Model: "CNN_LSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 14, 512)        │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 7, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 7, 512)         │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 7, 512)         │     2,099,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 7, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 7, 256)         │       393,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 3, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 3, 256)         │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 3, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 1, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,261,953 (12.44 MB)
#  Trainable params: 3,260,161 (12.44 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# CNN-BiLSTM Model Summary:
# Model: "CNN_BiLSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 14, 512)        │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 7, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 7, 512)         │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 7, 512)         │     1,574,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 7, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 7, 256)         │       393,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 3, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 3, 256)         │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 3, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 1, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,573,825 (9.82 MB)
#  Trainable params: 2,572,033 (9.81 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# CNN-GRU Model Summary:
# Model: "CNN_GRU"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_2 (Reshape)             │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 14, 512)        │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 7, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 7, 512)         │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 7, 512)         │     1,575,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 7, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 7, 256)         │       393,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 3, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 3, 256)         │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 3, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 1, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 128)            │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,575,617 (9.83 MB)
#  Trainable params: 2,573,825 (9.82 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# CNN-BiGRU Model Summary:
# Model: "CNN_BiGRU"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 14, 512)        │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_9 (MaxPooling1D)  │ (None, 7, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 7, 512)         │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 7, 512)         │     1,182,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 7, 512)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 7, 256)         │       393,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_10 (MaxPooling1D) │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 3, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_4 (Bidirectional) │ (None, 3, 256)         │       296,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 3, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 3, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_11 (MaxPooling1D) │ (None, 1, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 1, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_5 (Bidirectional) │ (None, 128)            │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,059,521 (7.86 MB)
#  Trainable params: 2,057,729 (7.85 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

dl_history = {}

print('✅ Starting Deep Learning Models Training....\n')

for name, model in dl_models.items():
    print(f"{'='*50}\nTraining {name} Model\n{'='*50}")
    
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    checkpoint = ModelCheckpoint(f'{name}_Model.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=0)
    
    history = model.fit(
        X_train, Y_train, 
        epochs=100, 
        batch_size=32, 
        validation_data=(X_test, Y_test), 
        callbacks=[early_stop, checkpoint], 
        verbose=1
    )
    
    dl_history[name] = history
    print(f"✅ {name} Training Completed. Best model saved as '{name}_Model.keras'\n")
# Out:
# ✅ Starting Deep Learning Models Training....
#
# ==================================================
# Training DNN Model
# ==================================================
# Epoch 1/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 38.0237 - r2_score: -5.3618 - val_loss: 17.1149 - val_r2_score: -0.3432
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.8408 - r2_score: 0.5876 - val_loss: 7.1764 - val_r2_score: 0.7480
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5337 - r2_score: 0.7184 - val_loss: 7.2547 - val_r2_score: 0.7622
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.7747 - r2_score: 0.7726 - val_loss: 4.1623 - val_r2_score: 0.9115
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.2391 - r2_score: 0.8035 - val_loss: 3.6653 - val_r2_score: 0.9314
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.1064 - r2_score: 0.8149 - val_loss: 3.4036 - val_r2_score: 0.9412
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.8174 - r2_score: 0.8311 - val_loss: 3.2081 - val_r2_score: 0.9477
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.7324 - r2_score: 0.8367 - val_loss: 3.2838 - val_r2_score: 0.9460
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.4648 - r2_score: 0.8471 - val_loss: 3.2116 - val_r2_score: 0.9484
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.5197 - r2_score: 0.8458 - val_loss: 2.9141 - val_r2_score: 0.9558
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.2180 - r2_score: 0.8615 - val_loss: 2.9358 - val_r2_score: 0.9557
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.3873 - r2_score: 0.8562 - val_loss: 3.4362 - val_r2_score: 0.9425
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.1256 - r2_score: 0.8679 - val_loss: 2.8651 - val_r2_score: 0.9586
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.0494 - r2_score: 0.8724 - val_loss: 3.2723 - val_r2_score: 0.9465
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.0364 - r2_score: 0.8701 - val_loss: 3.3039 - val_r2_score: 0.9460
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.9688 - r2_score: 0.8745 - val_loss: 2.8553 - val_r2_score: 0.9590
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.9807 - r2_score: 0.8745 - val_loss: 3.0570 - val_r2_score: 0.9538
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.0453 - r2_score: 0.8721 - val_loss: 3.0566 - val_r2_score: 0.9527
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.9432 - r2_score: 0.8758 - val_loss: 3.0491 - val_r2_score: 0.9520
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.9315 - r2_score: 0.8797 - val_loss: 3.0878 - val_r2_score: 0.9518
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.8492 - r2_score: 0.8820 - val_loss: 3.1475 - val_r2_score: 0.9492
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.7833 - r2_score: 0.8837 - val_loss: 3.3897 - val_r2_score: 0.9416
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.7856 - r2_score: 0.8831 - val_loss: 3.1324 - val_r2_score: 0.9510
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.6623 - r2_score: 0.8911 - val_loss: 3.1462 - val_r2_score: 0.9496
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.8586 - r2_score: 0.8804 - val_loss: 3.1481 - val_r2_score: 0.9506
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.7735 - r2_score: 0.8841 - val_loss: 2.9527 - val_r2_score: 0.9564
# ✅ DNN Training Completed. Best model saved as 'DNN_Model.keras'
#
# ==================================================
# Training CNN-LSTM Model
# ==================================================
# Epoch 1/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - loss:
100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 3.9971 - r2_score: 0.9194 - val_loss: 3.3479 - val_r2_score: 0.9421
# ✅ CNN-BiGRU Training Completed. Best model saved as 'CNN-BiGRU_Model.keras'

# %%
results = []

for name, model in dl_models.items():
    Y_pred_train = model.predict(X_train, verbose=0)
    Y_pred_test = model.predict(X_test, verbose=0)
    
    train_r2 = r2_score(Y_train, Y_pred_train)
    test_r2 = r2_score(Y_test, Y_pred_test)
    
    results.append({"DL Model": name, "Train R²-Score": train_r2, "Test R²-Score": test_r2})

results_df = pd.DataFrame(results)
display(results_df)
# Out:
#      DL Model  Train R²-Score  Test R²-Score
# 0         DNN        0.963356       0.959011
# 1    CNN-LSTM        0.952887       0.939900
# 2  CNN-BiLSTM        0.958954       0.938759
# 3     CNN-GRU        0.960166       0.948928
# 4   CNN-BiGRU        0.965681       0.944764

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_models = len(dl_models)
fig, axes = plt.subplots(num_models, 2, figsize=(15, 4 * num_models))

for i, (name, history) in enumerate(dl_history.items()):
    # 1. Plot R²-Score
    axes[i, 0].plot(history.history['r2_score'], label='Train R²-Score', color='blue')
    axes[i, 0].plot(history.history['val_r2_score'], label='Validation R²-Score', color='orange')
    axes[i, 0].set_title(f'{name} - R²-Score')
    axes[i, 0].set_xlabel('Epochs')
    axes[i, 0].set_ylabel('R²-Score')
    axes[i, 0].legend()
    axes[i, 0].grid(True)

    # 2. Plot Loss
    axes[i, 1].plot(history.history['loss'], label='Train Loss (MAE)', color='blue')
    axes[i, 1].plot(history.history['val_loss'], label='Validation Loss (MAE)', color='orange')
    axes[i, 1].set_title(f'{name} - Loss')
    axes[i, 1].set_xlabel('Epochs')
    axes[i, 1].set_ylabel('Loss')
    axes[i, 1].legend()
    axes[i, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model

# Prepare the full dataset for prediction
X_full = df.iloc[:, :14].copy()

encoders = joblib.load('Label-Encoders.bin')
for column in X_full.select_dtypes(include='object'):
    X_full[column] = encoders[column].transform(X_full[column])

scaler = joblib.load('Standard-Scaler.bin')
X_full_scaled = scaler.transform(X_full)

print("Generating predictions for the full dataset using all Deep Learning models...\n")

# Predict with each saved model and append as a new column
for name in dl_models.keys():
    saved_model = load_model(f'{name}_Model.keras')
    predictions = saved_model.predict(X_full_scaled, verbose=0)
    df[f'{name}_Predicted_Output'] = predictions

# Save final dataset
output_file = 'smartphone_battery_health_with_all_predictions.csv'
df.to_csv(output_file, index=False)
print(f"✅ Predictions saved successfully to: {output_file}\n")

# View the original targets alongside the new predictions
display_columns = ['current_battery_health_percent'] + [f'{name}_Predicted_Output' for name in dl_models.keys()]
display(df[display_columns].head())
# Out:
# Generating predictions for the full dataset using all Deep Learning models...
#
# ✅ Predictions saved successfully to: smartphone_battery_health_with_all_predictions.csv
#    current_battery_health_percent  DNN_Predicted_Output  \
# 0                            32.8             25.757353
# 1                            50.3             53.173023
# 2                            66.1             71.923836
# 3                            46.8             46.292824
# 4                            67.2             68.917213
#
#    CNN-LSTM_Predicted_Output  CNN-BiLSTM_Predicted_Output  \
# 0                  31.582243                    32.429699
# 1                  48.413033                    48.852669
# 2                  71.946075                    74.393059
# 3                  42.675194                    45.397274
# 4                  74.739624                    69.562241
#
#    CNN-GRU_Predicted_Output  CNN-BiGRU_Predicted_Output
# 0                 30.639713                   31.013945
# 1                 49.830650                   50.367580
# 2                 73.944748                   68.098442
# 3                 45.085114                   43.237278
# 4                 68.852310                   68.418053
