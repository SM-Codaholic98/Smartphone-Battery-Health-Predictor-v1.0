# %%
import pandas as pd
import numpy as np

# Load and merge datasets
independent_features = pd.read_csv('smartphone_battery_features.csv')
dependent_feature = pd.read_csv('smartphone_battery_targets.csv')
df = independent_features.merge(dependent_feature, on='Device_ID', how='inner')

display(df.head())
# Out:
#                               Device_ID  device_age_months  \
# 0  207dd94c-0430-43aa-b388-4893447e628e                 38
# 1  3f4d1d33-ba89-4814-a168-7b4cc75be26b                 28
# 2  b4adca05-564f-4b70-ab69-e8d66e656463                 14
# 3  4147e039-31b7-480a-bbc9-03cd0f66e9f1                 42
# 4  3f9b0fb7-73c2-4ab7-8e30-7b492097a3f5                  7
#
#    battery_capacity_mah  avg_screen_on_hours_per_day  \
# 0                  4500                          7.1
# 1                  3000                          6.8
# 2                  3000                          7.2
# 3                  3000                          5.5
# 4                  3000                          7.6
#
#    avg_charging_cycles_per_week  avg_battery_temp_celsius  \
# 0                          11.4                      34.8
# 1                          10.3                      35.4
# 2                          11.2                      29.4
# 3                           8.3                      32.8
# 4                          11.6                      38.7
#
#    fast_charging_usage_percent  overnight_charging_freq_per_week  \
# 0                         90.8                                 7
# 1                         60.6                                 2
# 2                         29.3                                 4
# 3                         62.5                                 0
# 4                         85.4                                 6
#
#    gaming_hours_per_week  video_streaming_hours_per_week  \
# 0                    7.9                            14.0
# 1                    8.6                            11.0
# 2                    0.3                            10.3
# 3                    1.9                             4.9
# 4                    7.9                             9.3
#
#   background_app_usage_level signal_strength_avg  charging_habit_score  \
# 0                     Medium                Poor                     4
# 1                     Medium                Good                     7
# 2                     Medium                Good                     6
# 3                     Medium                Good                     8
# 4                       High                Good                     5
#
#    usage_intensity_score  thermal_stress_index  \
# 0                   10.0                  4.04
# 1                   10.0                  4.23
# 2                   10.0                  2.21
# 3                   10.0                  3.13
# 4                   10.0                  4.95
#
#    current_battery_health_percent recommended_action
# 0                            32.8       Change Phone
# 1                            50.3    Replace Battery
# 2                            66.1    Replace Battery
# 3                            46.8       Change Phone
# 4                            67.2    Replace Battery

# %%
print("Shape before dropping ID:", df.shape)
df.drop(columns=['Device_ID'], inplace=True)
print("Shape after dropping ID:", df.shape)

print("\nNull Values:\n", df.isnull().sum())
print("\nDuplicated Rows:", df.duplicated().sum())
# Out:
# Shape before dropping ID: (5000, 17)
# Shape after dropping ID: (5000, 16)
#
# Null Values:
#  device_age_months                   0
# battery_capacity_mah                0
# avg_screen_on_hours_per_day         0
# avg_charging_cycles_per_week        0
# avg_battery_temp_celsius            0
# fast_charging_usage_percent         0
# overnight_charging_freq_per_week    0
# gaming_hours_per_week               0
# video_streaming_hours_per_week      0
# background_app_usage_level          0
# signal_strength_avg                 0
# charging_habit_score                0
# usage_intensity_score               0
# thermal_stress_index                0
# current_battery_health_percent      0
# recommended_action                  0
# dtype: int64
#
# Duplicated Rows: 0

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:, :14]
Y = df.iloc[:, 14]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
display(X_train.head())
# Out:
#       device_age_months  battery_capacity_mah  avg_screen_on_hours_per_day  \
# 1840                 13                  5000                          5.7
# 2115                 42                  3000                         10.7
# 4437                 22                  4000                          6.4
# 1146                 32                  3000                          3.5
# 2486                 15                  4000                          7.1
#
#       avg_charging_cycles_per_week  avg_battery_temp_celsius  \
# 1840                           8.4                      34.6
# 2115                          14.2                      36.5
# 4437                           8.8                      33.6
# 1146                           3.6                      32.4
# 2486                          11.5                      38.2
#
#       fast_charging_usage_percent  overnight_charging_freq_per_week  \
# 1840                         62.0                                 1
# 2115                         97.1                                 1
# 4437                         61.1                                 5
# 1146                         22.8                                 7
# 2486                         68.6                                 5
#
#       gaming_hours_per_week  video_streaming_hours_per_week  \
# 1840                    4.2                             7.3
# 2115                    7.4                            12.8
# 4437                    4.9                             8.6
# 1146                    5.6                             8.0
# 2486                   12.6                            11.0
#
#      background_app_usage_level signal_strength_avg  charging_habit_score  \
# 1840                     Medium                Good                     8
# 2115                       High                Good                     6
# 4437                     Medium            Moderate                     5
# 1146                       High                Good                     6
# 2486                       High                Good                     6
#
#       usage_intensity_score  thermal_stress_index
# 1840                   10.0                  3.74
# 2115                   10.0                  4.41
# 4437                   10.0                  3.53
# 1146                   10.0                  3.31
# 2486                   10.0                  5.18

# %%
import joblib
from sklearn.preprocessing import LabelEncoder

label_encoders = {}

for column in X_train.select_dtypes(include='object'):
    le = LabelEncoder()
    X_train[column] = le.fit_transform(X_train[column])
    X_test[column] = le.transform(X_test[column])
    label_encoders[column] = le
    
joblib.dump(label_encoders, 'Label-Encoders.bin')
print("✅ Label Encoders saved as 'Label-Encoders.bin'")
# Out:
# ✅ Label Encoders saved as 'Label-Encoders.bin'

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
X_train = std_scaler.fit_transform(X_train)
X_test = std_scaler.transform(X_test)
    
joblib.dump(std_scaler, 'Standard-Scaler.bin')
print("✅ Standard Scaler saved as 'Standard-Scaler.bin'")
print(f'Training data input shape : {X_train.shape}')
print(f'Testing data input shape  : {X_test.shape}')
# Out:
# ✅ Standard Scaler saved as 'Standard-Scaler.bin'
# Training data input shape : (3500, 14)
# Testing data input shape  : (1500, 14)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor, XGBRFRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.metrics import r2_score
import os

os.environ["LOKY_MAX_CPU_COUNT"] = "8"

classifier_model_dict = {
    'Random Forest Regressor': RandomForestRegressor(random_state=42),
    'AdaBoost Regressor': AdaBoostRegressor(random_state=42),
    'Gradient Boosting Regressor': GradientBoostingRegressor(random_state=42),
    'XGBoost Regressor': XGBRegressor(random_state=42),
    'XGBoost RF-Booster': XGBRFRegressor(random_state=42),
    'LightGBM Regressor': LGBMRegressor(random_state=42),
    'CatBoost Regressor': CatBoostRegressor(verbose=0, random_state=42)
}

for model_name, model in classifier_model_dict.items():
    print(f'\n-------------------- {model_name} --------------------')
    model.fit(X_train, Y_train)
    Y_pred_train = model.predict(X_train)
    Y_pred_test = model.predict(X_test)
    
    print(f"Train R²-Score : {r2_score(Y_train, Y_pred_train):.4f}")
    print(f"Test R²-Score  : {r2_score(Y_test, Y_pred_test):.4f}")
# Out:
# -------------------- Random Forest Regressor --------------------
# Train R²-Score : 0.9941
# Test R²-Score  : 0.9579
#
# -------------------- AdaBoost Regressor --------------------
# Train R²-Score : 0.9366
# Test R²-Score  : 0.9300
#
# -------------------- Gradient Boosting Regressor --------------------
# Train R²-Score : 0.9728
# Test R²-Score  : 0.9635
#
# -------------------- XGBoost Regressor --------------------
# Train R²-Score : 0.9967
# Test R²-Score  : 0.9572
#
# -------------------- XGBoost RF-Booster --------------------
# Train R²-Score : 0.9564
# Test R²-Score  : 0.9424
#
# -------------------- LightGBM Regressor --------------------
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000211 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1321
# [LightGBM] [Info] Number of data points in the train set: 3500, number of used features: 13
# [LightGBM] [Info] Start training from score 62.597257
# Train R²-Score : 0.9854
# Test R²-Score  : 0.9620
#
# -------------------- CatBoost Regressor --------------------
# d:\Predictor_Applications v1.2\Smartphone_Battery_Health_Predictor v1.0\venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# d:\Predictor_Applications v1.2\Smartphone_Battery_Health_Predictor v1.0\venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Train R²-Score : 0.9873
# Test R²-Score  : 0.9645

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Dropout, Reshape, Conv1D, MaxPooling1D, LSTM, GRU, Bidirectional

# 1. Base Deep Neural Network (DNN)
def build_dnn(input_shape):
    inp = Input(shape=input_shape)
    
    x = Dense(256, activation='relu')(inp)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(64, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(32, activation='relu')(x)
    out = Dense(1)(x)
    
    model = Model(inputs=inp, outputs=out, name="DNN")
    model.compile(optimizer='adam', loss='mae', metrics=['r2_score'])
    return model

# 2. Advanced 3-Block Hybrid Convolutional-Recurrent Networks
def build_advanced_hybrid_dl(input_shape, rnn_type, bidirectional=False, name="Hybrid"):
    inp = Input(shape=input_shape)
    
    # Reshape 1D tabular features to 3D tensor (Batch, Timesteps, Features) for Conv1D
    # Timesteps start at 14
    x = Reshape((input_shape[0], 1))(inp)
    
    # ---------------- Block 1 ----------------
    x = Conv1D(256, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x) # Timesteps reduce to 7
    x = BatchNormalization()(x)
    
    rnn_units_1 = 128 if bidirectional else 256
    rnn_layer_1 = LSTM(rnn_units_1, return_sequences=True) if rnn_type == 'LSTM' else GRU(rnn_units_1, return_sequences=True)
    x = Bidirectional(rnn_layer_1)(x) if bidirectional else rnn_layer_1(x)
    x = Dropout(0.2)(x)
    
    # ---------------- Block 2 ----------------
    x = Conv1D(128, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x) # Timesteps reduce to 3
    x = BatchNormalization()(x)
    
    rnn_units_2 = 64 if bidirectional else 128
    rnn_layer_2 = LSTM(rnn_units_2, return_sequences=True) if rnn_type == 'LSTM' else GRU(rnn_units_2, return_sequences=True)
    x = Bidirectional(rnn_layer_2)(x) if bidirectional else rnn_layer_2(x)
    x = Dropout(0.2)(x)
    
    # ---------------- Block 3 ----------------
    x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x) # Timesteps reduce to 1
    x = BatchNormalization()(x)
    
    rnn_units_3 = 32 if bidirectional else 64
    rnn_layer_3 = LSTM(rnn_units_3, return_sequences=False) if rnn_type == 'LSTM' else GRU(rnn_units_3, return_sequences=False)
    x = Bidirectional(rnn_layer_3)(x) if bidirectional else rnn_layer_3(x)
    x = Dropout(0.2)(x)
    
    # ------------- Dense Output -------------
    x = Dense(32, activation='relu')(x)
    out = Dense(1)(x)
    
    model = Model(inputs=inp, outputs=out, name=name)
    model.compile(optimizer='adam', loss='mae', metrics=['r2_score'])
    return model

# Define input shape
input_shape = (X_train.shape[1],)

# Initialize all 5 models
dl_models = {
    "DNN": build_dnn(input_shape),
    "CNN-LSTM": build_advanced_hybrid_dl(input_shape, rnn_type='LSTM', bidirectional=False, name="CNN_LSTM"),
    "CNN-BiLSTM": build_advanced_hybrid_dl(input_shape, rnn_type='LSTM', bidirectional=True, name="CNN_BiLSTM"), 
    "CNN-GRU": build_advanced_hybrid_dl(input_shape, rnn_type='GRU', bidirectional=False, name="CNN_GRU"),
    "CNN-BiGRU": build_advanced_hybrid_dl(input_shape, rnn_type='GRU', bidirectional=True, name="CNN_BiGRU")
}

# Preview the architectures
for name, model in dl_models.items():
    print(f"\n{name} Model Summary:")
    model.summary()
# Out:
# DNN Model Summary:
# Model: "DNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │         3,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 48,897 (191.00 KB)
#  Trainable params: 48,001 (187.50 KB)
#  Non-trainable params: 896 (3.50 KB)
# CNN-LSTM Model Summary:
# Model: "CNN_LSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 14, 256)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 7, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 7, 256)         │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 7, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 3, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 3, 128)         │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 3, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 1, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 817,921 (3.12 MB)
#  Trainable params: 817,025 (3.12 MB)
#  Non-trainable params: 896 (3.50 KB)
# CNN-BiLSTM Model Summary:
# Model: "CNN_BiLSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 14, 256)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 7, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 7, 256)         │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 7, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 3, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 3, 128)         │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 3, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 1, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 64)             │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 645,889 (2.46 MB)
#  Trainable params: 644,993 (2.46 MB)
#  Non-trainable params: 896 (3.50 KB)
# CNN-GRU Model Summary:
# Model: "CNN_GRU"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_2 (Reshape)             │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 14, 256)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 7, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 7, 256)         │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 7, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 3, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 3, 128)         │        99,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 3, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 1, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 64)             │        24,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 646,785 (2.47 MB)
#  Trainable params: 645,889 (2.46 MB)
#  Non-trainable params: 896 (3.50 KB)
# CNN-BiGRU Model Summary:
# Model: "CNN_BiGRU"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 14)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 14, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 14, 256)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_9 (MaxPooling1D)  │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 7, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 7, 256)         │       296,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 7, 128)         │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_10 (MaxPooling1D) │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 3, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_4 (Bidirectional) │ (None, 3, 128)         │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 3, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_11 (MaxPooling1D) │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 1, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_5 (Bidirectional) │ (None, 64)             │        18,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 517,761 (1.98 MB)
#  Trainable params: 516,865 (1.97 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

dl_history = {}

print('✅ Starting Deep Learning Models Training....\n')

for name, model in dl_models.items():
    print(f"{'='*50}\nTraining {name} Model\n{'='*50}")
    
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    checkpoint = ModelCheckpoint(f'{name}_Model.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=0)
    
    history = model.fit(
        X_train, Y_train, 
        epochs=100, 
        batch_size=32, 
        validation_data=(X_test, Y_test), 
        callbacks=[early_stop, checkpoint], 
        verbose=1
    )
    
    dl_history[name] = history
    print(f"✅ {name} Training Completed. Best model saved as '{name}_Model.keras'\n")
# Out:
# ✅ Starting Deep Learning Models Training....
# ==================================================
# Training DNN Model
# ==================================================
# Epoch 1/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 56.2009 - r2_score: -10.1236 - val_loss: 49.2337 - val_r2_score: -7.7381
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.7271 - r2_score: -1.5305 - val_loss: 10.4519 - val_r2_score: 0.2673
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.0388 - r2_score: 0.4661 - val_loss: 4.6026 - val_r2_score: 0.8924
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9606 - r2_score: 0.6867 - val_loss: 4.3423 - val_r2_score: 0.9040
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9198 - r2_score: 0.6868 - val_loss: 3.5581 - val_r2_score: 0.9337
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4499 - r2_score: 0.7211 - val_loss: 3.8217 - val_r2_score: 0.9237
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1051 - r2_score: 0.7436 - val_loss: 3.2324 - val_r2_score: 0.9449
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9515 - r2_score: 0.7575 - val_loss: 3.2035 - val_r2_score: 0.9465
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1796 - r2_score: 0.7445 - val_loss: 3.2838 - val_r2_score: 0.9453
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7682 - r2_score: 0.7688 - val_loss: 3.4978 - val_r2_score: 0.9388
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6221 - r2_score: 0.7762 - val_loss: 3.3510 - val_r2_score: 0.9427
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4098 - r2_score: 0.7913 - val_loss: 3.0379 - val_r2_score: 0.9520
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4977 - r2_score: 0.7897 - val_loss: 3.3336 - val_r2_score: 0.9447
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5433 - r2_score: 0.7871 - val_loss: 2.8548 - val_r2_score: 0.9582
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2105 - r2_score: 0.8057 - val_loss: 2.9590 - val_r2_score: 0.9550
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1114 - r2_score: 0.8130 - val_loss: 2.9464 - val_r2_score: 0.9554
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0603 - r2_score: 0.8184 - val_loss: 3.3994 - val_r2_score: 0.9413
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2974 - r2_score: 0.8043 - val_loss: 2.9361 - val_r2_score: 0.9562
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0268 - r2_score: 0.8180 - val_loss: 3.2088 - val_r2_score: 0.9468
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1568 - r2_score: 0.8104 - val_loss: 2.9130 - val_r2_score: 0.9566
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8576 - r2_score: 0.8283 - val_loss: 3.0660 - val_r2_score: 0.9524
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7460 - r2_score: 0.8347 - val_loss: 3.0477 - val_r2_score: 0.9527
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6608 - r2_score: 0.8395 - val_loss: 2.9121 - val_r2_score: 0.9573
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6304 - r2_score: 0.8391 - val_loss: 3.0176 - val_r2_score: 0.9539
# ✅ DNN Training Completed. Best model saved as 'DNN_Model.keras'
#
# ==================================================
# Training CNN-LSTM Model
# ==================================================
# Epoch 1/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - loss: 53.0502 - r2_score: -9.0817 - val_loss: 35.8359 - val_r2_score: -3.9870
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 23.0315 - r2_score: -1.5024 - val_loss: 14.3872 - val_r2_score: 0.0020
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 9.8709 - r2_score: 0.5089 - val_loss: 7.3310 - val_r2_score: 0.7320
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 7.3601 - r2_score: 0.7217 - val_loss: 4.8191 - val_r2_score: 0.8802
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 6.4594 - r2_score: 0.7880 - val_loss: 4.9220 - val_r2_score: 0.8818
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 6.2738 - r2_score: 0.8039 - val_loss: 4.3456 - val_r2_score: 0.9015
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.9854 - r2_score: 0.8206 - val_loss: 3.8885 - val_r2_score: 0.9220
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 5.9472 - r2_score: 0.8224 - val_loss: 4.0946 - val_r2_score: 0.9131
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.7426 - r2_score: 0.8338 - val_loss: 3.7835 - val_r2_score: 0.9274
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 5.7445 - r2_score: 0.8352 - val_loss: 3.8975 - val_r2_score: 0.9233
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.5961 - r2_score: 0.8401 - val_loss: 3.6253 - val_r2_score: 0.9317
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 5.5996 - r2_score: 0.8387 - val_loss: 3.7326 - val_r2_score: 0.9294
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 5.5116 - r2_score: 0.8459 - val_loss: 3.7585 - val_r2_score: 0.9271
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.6271 - r2_score: 0.8409 - val_loss: 3.6661 - val_r2_score: 0.9322
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.4259 - r2_score: 0.8503 - val_loss: 3.6079 - val_r2_score: 0.9338
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.4905 - r2_score: 0.8472 - val_loss: 3.5485 - val_r2_score: 0.9356
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.4042 - r2_score: 0.8538 - val_loss: 3.5606 - val_r2_score: 0.9348
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 5.3065 - r2_score: 0.8568 - val_loss: 3.3959 - val_r2_score: 0.9392
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 5.4652 - r2_score: 0.8476 - val_loss: 3.5961 - val_r2_score: 0.9341
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.1468 - r2_score: 0.8677 - val_loss: 3.6386 - val_r2_score: 0.9315
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.2454 - r2_score: 0.8617 - val_loss: 3.8127 - val_r2_score: 0.9248
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 5.1615 - r2_score: 0.8658 - val_loss: 3.3541 - val_r2_score: 0.9417
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.1966 - r2_score: 0.8610 - val_loss: 4.2378 - val_r2_score: 0.9128
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.1392 - r2_score: 0.8666 - val_loss: 3.6269 - val_r2_score: 0.9323
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.0522 - r2_score: 0.8708 - val_loss: 3.4223 - val_r2_score: 0.9407
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 5.1442 - r2_score: 0.8651 - val_loss: 3.6885 - val_r2_score: 0.9309
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.1622 - r2_score: 0.8644 - val_loss: 3.6548 - val_r2_score: 0.9325
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.2883 - r2_score: 0.8570 - val_loss: 3.5447 - val_r2_score: 0.9349
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.0077 - r2_score: 0.8734 - val_loss: 3.5444 - val_r2_score: 0.9363
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.0454 - r2_score: 0.8701 - val_loss: 3.4548 - val_r2_score: 0.9377
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.9394 - r2_score: 0.8771 - val_loss: 3.3420 - val_r2_score: 0.9421
# Epoch 32/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9452 - r2_score: 0.8762 - val_loss: 3.6700 - val_r2_score: 0.9313
# Epoch 33/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9850 - r2_score: 0.8738 - val_loss: 3.7227 - val_r2_score: 0.9299
# Epoch 34/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.8936 - r2_score: 0.8781 - val_loss: 3.6204 - val_r2_score: 0.9327
# Epoch 35/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9720 - r2_score: 0.8745 - val_loss: 3.3909 - val_r2_score: 0.9407
# Epoch 36/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9873 - r2_score: 0.8728 - val_loss: 3.4848 - val_r2_score: 0.9382
# Epoch 37/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.8566 - r2_score: 0.8813 - val_loss: 3.3293 - val_r2_score: 0.9434
# Epoch 38/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.7388 - r2_score: 0.8869 - val_loss: 3.4133 - val_r2_score: 0.9404
# Epoch 39/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9126 - r2_score: 0.8777 - val_loss: 3.8765 - val_r2_score: 0.9236
# Epoch 40/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.7975 - r2_score: 0.8840 - val_loss: 3.3235 - val_r2_score: 0.9433
# Epoch 41/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.6754 - r2_score: 0.8888 - val_loss: 3.2739 - val_r2_score: 0.9454
# Epoch 42/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.6156 - r2_score: 0.8912 - val_loss: 3.4194 - val_r2_score: 0.9403
# Epoch 43/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.8637 - r2_score: 0.8787 - val_loss: 3.4636 - val_r2_score: 0.9360
# Epoch 44/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.8785 - r2_score: 0.8807 - val_loss: 4.2914 - val_r2_score: 0.9116
# Epoch 45/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.8469 - r2_score: 0.8812 - val_loss: 3.7878 - val_r2_score: 0.9283
# Epoch 46/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 4.6832 - r2_score: 0.8871 - val_loss: 3.6418 - val_r2_score: 0.9327
# Epoch 47/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.6632 - r2_score: 0.8892 - val_loss: 3.2897 - val_r2_score: 0.9444
# Epoch 48/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.5309 - r2_score: 0.8967 - val_loss: 3.1286 - val_r2_score: 0.9492
# Epoch 49/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.5973 - r2_score: 0.8921 - val_loss: 3.1692 - val_r2_score: 0.9474
# Epoch 50/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.5489 - r2_score: 0.8954 - val_loss: 3.4060 - val_r2_score: 0.9418
# Epoch 51/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.5273 - r2_score: 0.8956 - val_loss: 3.4188 - val_r2_score: 0.9403
# Epoch 52/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.6024 - r2_score: 0.8925 - val_loss: 4.2039 - val_r2_score: 0.9140
# Epoch 53/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.6647 - r2_score: 0.8886 - val_loss: 3.7186 - val_r2_score: 0.9256
# Epoch 54/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.5190 - r2_score: 0.8955 - val_loss: 3.3033 - val_r2_score: 0.9456
# Epoch 55/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.4106 - r2_score: 0.8999 - val_loss: 3.4335 - val_r2_score: 0.9380
# Epoch 56/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.3297 - r2_score: 0.9029 - val_loss: 3.3824 - val_r2_score: 0.9414
# Epoch 57/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.3849 - r2_score: 0.9024 - val_loss: 3.1818 - val_r2_score: 0.9467
# Epoch 58/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.2460 - r2_score: 0.9069 - val_loss: 3.3967 - val_r2_score: 0.9417
# ✅ CNN-LSTM Training Completed. Best model saved as 'CNN-LSTM_Model.keras'
#
# ==================================================
# Training CNN-BiLSTM Model
# ==================================================
# Epoch 1/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 52.2260 - r2_score: -8.8266 - val_loss: 33.8565 - val_r2_score: -3.5381
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 23.1168 - r2_score: -1.6589 - val_loss: 11.2895 - val_r2_score: 0.3107
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 10.3287 - r2_score: 0.4009 - val_loss: 8.2221 - val_r2_score: 0.6533
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 7.2111 - r2_score: 0.7263 - val_loss: 5.3112 - val_r2_score: 0.8509
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 6.7037 - r2_score: 0.7668 - val_loss: 4.3412 - val_r2_score: 0.8993
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.0197 - r2_score: 0.8167 - val_loss: 5.4318 - val_r2_score: 0.8568
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.9738 - r2_score: 0.8174 - val_loss: 3.7650 - val_r2_score: 0.9266
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.8678 - r2_score: 0.8270 - val_loss: 3.4274 - val_r2_score: 0.9391
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.6249 - r2_score: 0.8377 - val_loss: 4.5251 - val_r2_score: 0.9013
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.7367 - r2_score: 0.8316 - val_loss: 3.6579 - val_r2_score: 0.9335
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.6047 - r2_score: 0.8390 - val_loss: 3.6022 - val_r2_score: 0.9330
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.6584 - r2_score: 0.8424 - val_loss: 3.4045 - val_r2_score: 0.9390
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.3766 - r2_score: 0.8536 - val_loss: 3.5962 - val_r2_score: 0.9321
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.4390 - r2_score: 0.8484 - val_loss: 4.0342 - val_r2_score: 0.9100
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.3497 - r2_score: 0.8523 - val_loss: 3.9860 - val_r2_score: 0.9173
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 5.4943 - r2_score: 0.8479 - val_loss: 3.5415 - val_r2_score: 0.9352
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.2780 - r2_score: 0.8581 - val_loss: 3.2873 - val_r2_score: 0.9429
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.3543 - r2_score: 0.8562 - val_loss: 3.5387 - val_r2_score: 0.9348
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.2603 - r2_score: 0.8602 - val_loss: 3.2535 - val_r2_score: 0.9449
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.1885 - r2_score: 0.8631 - val_loss: 3.7200 - val_r2_score: 0.9303
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.0693 - r2_score: 0.8684 - val_loss: 3.8704 - val_r2_score: 0.9249
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.2513 - r2_score: 0.8589 - val_loss: 3.2877 - val_r2_score: 0.9438
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.1841 - r2_score: 0.8646 - val_loss: 3.5681 - val_r2_score: 0.9357
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.0945 - r2_score: 0.8688 - val_loss: 4.5218 - val_r2_score: 0.9038
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.9392 - r2_score: 0.8767 - val_loss: 3.5872 - val_r2_score: 0.9356
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 4.9098 - r2_score: 0.8753 - val_loss: 3.3127 - val_r2_score: 0.9428
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.9696 - r2_score: 0.8726 - val_loss: 3.7015 - val_r2_score: 0.9299
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.1323 - r2_score: 0.8676 - val_loss: 3.3165 - val_r2_score: 0.9437
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 4.9965 - r2_score: 0.8725 - val_loss: 3.5383 - val_r2_score: 0.9347
# ✅ CNN-BiLSTM Training Completed. Best model saved as 'CNN-BiLSTM_Model.keras'
#
# ==================================================
# Training CNN-GRU Model
# ==================================================
# Epoch 1/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - loss: 51.5336 - r2_score: -8.6040 - val_loss: 36.0714 - val_r2_score: -4.0313
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 23.0497 - r2_score: -1.4110 - val_loss: 14.7188 - val_r2_score: 0.0023
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 9.8849 - r2_score: 0.5021 - val_loss: 5.9750 - val_r2_score: 0.8229
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 7.0948 - r2_score: 0.7428 - val_loss: 5.9784 - val_r2_score: 0.8085
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 7.0857 - r2_score: 0.7463 - val_loss: 4.5591 - val_r2_score: 0.8901
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 6.3597 - r2_score: 0.7938 - val_loss: 3.7715 - val_r2_score: 0.9273
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 6.2249 - r2_score: 0.8009 - val_loss: 3.8010 - val_r2_score: 0.9284
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 6.0500 - r2_score: 0.8149 - val_loss: 3.6319 - val_r2_score: 0.9313
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.8650 - r2_score: 0.8229 - val_loss: 3.7265 - val_r2_score: 0.9274
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 5.9700 - r2_score: 0.8189 - val_loss: 3.5244 - val_r2_score: 0.9347
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.5684 - r2_score: 0.8405 - val_loss: 4.0137 - val_r2_score: 0.9189
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.6446 - r2_score: 0.8346 - val_loss: 3.7072 - val_r2_score: 0.9296
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.6306 - r2_score: 0.8362 - val_loss: 3.8406 - val_r2_score: 0.9258
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.6433 - r2_score: 0.8356 - val_loss: 3.6301 - val_r2_score: 0.9344
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.8694 - r2_score: 0.8277 - val_loss: 3.7347 - val_r2_score: 0.9233
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.6529 - r2_score: 0.8368 - val_loss: 3.6340 - val_r2_score: 0.9332
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 5.4813 - r2_score: 0.8450 - val_loss: 3.3459 - val_r2_score: 0.9425
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.3646 - r2_score: 0.8527 - val_loss: 3.6564 - val_r2_score: 0.9336
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 5.3678 - r2_score: 0.8533 - val_loss: 3.4572 - val_r2_score: 0.9400
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.3798 - r2_score: 0.8527 - val_loss: 4.1113 - val_r2_score: 0.9137
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.2300 - r2_score: 0.8587 - val_loss: 3.6866 - val_r2_score: 0.9302
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.3985 - r2_score: 0.8513 - val_loss: 3.6486 - val_r2_score: 0.9320
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.4762 - r2_score: 0.8409 - val_loss: 3.5250 - val_r2_score: 0.9356
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.4133 - r2_score: 0.8484 - val_loss: 3.7517 - val_r2_score: 0.9281
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 5.2559 - r2_score: 0.8583 - val_loss: 3.7708 - val_r2_score: 0.9292
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.1422 - r2_score: 0.8581 - val_loss: 3.4752 - val_r2_score: 0.9383
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.0664 - r2_score: 0.8677 - val_loss: 4.9145 - val_r2_score: 0.8882
# ✅ CNN-GRU Training Completed. Best model saved as 'CNN-GRU_Model.keras'
#
# ==================================================
# Training CNN-BiGRU Model
# ==================================================
# Epoch 1/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 56.8595 - r2_score: -10.4219 - val_loss: 44.5676 - val_r2_score: -6.6442
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 25.8346 - r2_score: -2.3922 - val_loss: 13.5112 - val_r2_score: 0.1234
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 9.6243 - r2_score: 0.4385 - val_loss: 11.2610 - val_r2_score: 0.4203
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.5908 - r2_score: 0.7621 - val_loss: 6.1258 - val_r2_score: 0.7929
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 6.0919 - r2_score: 0.8129 - val_loss: 5.6759 - val_r2_score: 0.8103
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.7900 - r2_score: 0.8318 - val_loss: 3.6169 - val_r2_score: 0.9315
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.7208 - r2_score: 0.8367 - val_loss: 3.7671 - val_r2_score: 0.9287
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.7756 - r2_score: 0.8318 - val_loss: 4.5765 - val_r2_score: 0.8991
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.5649 - r2_score: 0.8443 - val_loss: 3.9522 - val_r2_score: 0.9222
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.5848 - r2_score: 0.8448 - val_loss: 3.7022 - val_r2_score: 0.9314
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.4536 - r2_score: 0.8520 - val_loss: 3.3096 - val_r2_score: 0.9440
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.3199 - r2_score: 0.8608 - val_loss: 3.3927 - val_r2_score: 0.9425
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.2652 - r2_score: 0.8612 - val_loss: 3.8583 - val_r2_score: 0.9240
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.2569 - r2_score: 0.8609 - val_loss: 3.6614 - val_r2_score: 0.9312
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.2423 - r2_score: 0.8629 - val_loss: 3.1863 - val_r2_score: 0.9476
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.1154 - r2_score: 0.8676 - val_loss: 4.1345 - val_r2_score: 0.9182
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.1376 - r2_score: 0.8676 - val_loss: 3.3471 - val_r2_score: 0.9422
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.9926 - r2_score: 0.8745 - val_loss: 3.5769 - val_r2_score: 0.9339
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.0255 - r2_score: 0.8709 - val_loss: 3.4968 - val_r2_score: 0.9207
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.8881 - r2_score: 0.7755 - val_loss: 4.2495 - val_r2_score: 0.8992
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.6549 - r2_score: 0.8281 - val_loss: 4.7866 - val_r2_score: 0.8047
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.2560 - r2_score: 0.8615 - val_loss: 3.8011 - val_r2_score: 0.9158
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 5.1468 - r2_score: 0.8683 - val_loss: 3.7912 - val_r2_score: 0.9260
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 4.8952 - r2_score: 0.8774 - val_loss: 3.7871 - val_r2_score: 0.9278
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 5.0932 - r2_score: 0.8714 - val_loss: 3.6560 - val_r2_score: 0.9293
# ✅ CNN-BiGRU Training Completed. Best model saved as 'CNN-BiGRU_Model.keras'

# %%
results = []

for name, model in dl_models.items():
    Y_pred_train = model.predict(X_train, verbose=0)
    Y_pred_test = model.predict(X_test, verbose=0)
    
    train_r2 = r2_score(Y_train, Y_pred_train)
    test_r2 = r2_score(Y_test, Y_pred_test)
    
    results.append({"DL Model": name, "Train R²-Score": train_r2, "Test R²-Score": test_r2})

results_df = pd.DataFrame(results)
display(results_df)
# Out:
#      DL Model  Train R²-Score  Test R²-Score
# 0         DNN        0.962851       0.958185
# 1    CNN-LSTM        0.967240       0.949176
# 2  CNN-BiLSTM        0.954827       0.944931
# 3     CNN-GRU        0.954484       0.942545
# 4   CNN-BiGRU        0.958411       0.947582

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_models = len(dl_models)
fig, axes = plt.subplots(num_models, 2, figsize=(15, 4 * num_models))

for i, (name, history) in enumerate(dl_history.items()):
    # 1. Plot R²-Score
    axes[i, 0].plot(history.history['r2_score'], label='Train R²-Score', color='blue')
    axes[i, 0].plot(history.history['val_r2_score'], label='Validation R²-Score', color='orange')
    axes[i, 0].set_title(f'{name} - R²-Score')
    axes[i, 0].set_xlabel('Epochs')
    axes[i, 0].set_ylabel('R²-Score')
    axes[i, 0].legend()
    axes[i, 0].grid(True)

    # 2. Plot Loss
    axes[i, 1].plot(history.history['loss'], label='Train Loss (MAE)', color='blue')
    axes[i, 1].plot(history.history['val_loss'], label='Validation Loss (MAE)', color='orange')
    axes[i, 1].set_title(f'{name} - Loss')
    axes[i, 1].set_xlabel('Epochs')
    axes[i, 1].set_ylabel('Loss')
    axes[i, 1].legend()
    axes[i, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model

# Prepare the full dataset for prediction
X_full = df.iloc[:, :14].copy()

encoders = joblib.load('Label-Encoders.bin')
for column in X_full.select_dtypes(include='object'):
    X_full[column] = encoders[column].transform(X_full[column])

scaler = joblib.load('Standard-Scaler.bin')
X_full_scaled = scaler.transform(X_full)

print("Generating predictions for the full dataset using all Deep Learning models...\n")

# Predict with each saved model and append as a new column
for name in dl_models.keys():
    saved_model = load_model(f'{name}_Model.keras')
    predictions = saved_model.predict(X_full_scaled, verbose=0)
    df[f'{name}_Predicted_Output'] = predictions

# Save final dataset
output_file = 'smartphone_battery_health_with_all_predictions.csv'
df.to_csv(output_file, index=False)
print(f"✅ Predictions saved successfully to: {output_file}\n")

# View the original targets alongside the new predictions
display_columns = ['current_battery_health_percent'] + [f'{name}_Predicted_Output' for name in dl_models.keys()]
display(df[display_columns].head())
# Out:
# Generating predictions for the full dataset using all Deep Learning models...
#
# ✅ Predictions saved successfully to: smartphone_battery_health_with_all_predictions.csv
#    current_battery_health_percent  DNN_Predicted_Output  \
# 0                            32.8             30.914202
# 1                            50.3             49.012177
# 2                            66.1             73.505157
# 3                            46.8             43.660309
# 4                            67.2             69.980614
#
#    CNN-LSTM_Predicted_Output  CNN-BiLSTM_Predicted_Output  \
# 0                  31.294804                    33.132153
# 1                  48.200954                    53.375282
# 2                  71.817398                    75.223785
# 3                  42.162579                    44.022316
# 4                  66.675247                    70.949936
#
#    CNN-GRU_Predicted_Output  CNN-BiGRU_Predicted_Output
# 0                 31.230825                   31.601751
# 1                 49.953911                   49.374466
# 2                 72.991531                   68.773598
# 3                 44.318417                   44.010830
# 4                 73.994614                   68.341759

# %%
df[display_columns].head(10)
# Out:
#    current_battery_health_percent  DNN_Predicted_Output  \
# 0                            32.8             30.914202
# 1                            50.3             49.012177
# 2                            66.1             73.505157
# 3                            46.8             43.660309
# 4                            67.2             69.980614
# 5                            69.5             71.030525
# 6                            35.5             36.969986
# 7                            66.3             69.474670
# 8                            56.7             52.784397
# 9                            85.2             81.960152
#
#    CNN-LSTM_Predicted_Output  CNN-BiLSTM_Predicted_Output  \
# 0                  31.294804                    33.132153
# 1                  48.200954                    53.375282
# 2                  71.817398                    75.223785
# 3                  42.162579                    44.022316
# 4                  66.675247                    70.949936
# 5                  69.287422                    65.956055
# 6                  37.537266                    32.548767
# 7                  68.786720                    66.407227
# 8                  54.993519                    55.412327
# 9                  79.926758                    78.148941
#
#    CNN-GRU_Predicted_Output  CNN-BiGRU_Predicted_Output
# 0                 31.230825                   31.601751
# 1                 49.953911                   49.374466
# 2                 72.991531                   68.773598
# 3                 44.318417                   44.010830
# 4                 73.994614                   68.341759
# 5                 65.926773                   65.555290
# 6                 35.584888                   33.519989
# 7                 68.990753                   67.878113
# 8                 56.085785                   52.394417
# 9                 84.170059                   81.304016
